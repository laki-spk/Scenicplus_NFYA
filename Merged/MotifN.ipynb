# %%
import pickle

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import sys
import os
_stderr = sys.stderr
null = open(os.devnull,'wb')

import os
work_dir = 'NFYA'

region_bin_topics_otsu = pickle.load(open(os.path.join(work_dir, 'scATAC/candidate_enhancers/region_bin_topics_otsu.pkl'), 'rb'))
region_bin_topics_top3k = pickle.load(open(os.path.join(work_dir, 'scATAC/candidate_enhancers/region_bin_topics_top3k.pkl'), 'rb'))
markers_dict = pickle.load(open(os.path.join(work_dir, 'scATAC/candidate_enhancers/markers_dict.pkl'), 'rb'))

# %%
#for DAR in markers_dict.keys():
#    regions = markers_dict[DAR].index[markers_dict[DAR].index.str.startswith('chr')] #only keep regions on known chromosomes
#    if len(regions) == 0:
#      print(DAR)
# Out:
# 3

# %%
#for DAR in markers_dict.keys():
#    regions = markers_dict[DAR].index[markers_dict[DAR].index.str.startswith('chr')] #only keep regions on known chromosomes
#    if len(regions) > 0:
#        region_sets['DARs'][DAR] = pr.PyRanges(region_names_to_coordinates(regions))

# %%
#import pyranges as pr
#from pycistarget.utils import region_names_to_coordinates
#region_sets = {}
#region_sets['topics_otsu'] = {}
#region_sets['topics_top_3'] = {}
#region_sets['DARs'] = {}
#for topic in region_bin_topics_otsu.keys():
#    regions = region_bin_topics_otsu[topic].index[region_bin_topics_otsu[topic].index.str.startswith('chr')] #only keep regions on known chromosomes
#    region_sets['topics_otsu'][topic] = pr.PyRanges(region_names_to_coordinates(regions))
#for topic in region_bin_topics_top3k.keys():
#    regions = region_bin_topics_top3k[topic].index[region_bin_topics_top3k[topic].index.str.startswith('chr')] #only keep regions on known chromosomes
#    region_sets['topics_top_3'][topic] = pr.PyRanges(region_names_to_coordinates(regions))
#for DAR in markers_dict.keys():
#    regions = markers_dict[DAR].index[markers_dict[DAR].index.str.startswith('chr')] #only keep regions on known chromosomes
#    if len(regions) > 0:
#        region_sets['DARs'][DAR] = pr.PyRanges(region_names_to_coordinates(regions))

# %%
#for key in region_sets.keys():
#    print(f'{key}: {region_sets[key].keys()}')
# Out:
# topics_otsu: dict_keys(['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5', 'Topic6', 'Topic7', 'Topic8', 'Topic9', 'Topic10', 'Topic11', 'Topic12', 'Topic13', 'Topic14', 'Topic15', 'Topic16'])
# topics_top_3: dict_keys(['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5', 'Topic6', 'Topic7', 'Topic8', 'Topic9', 'Topic10', 'Topic11', 'Topic12', 'Topic13', 'Topic14', 'Topic15', 'Topic16'])
# DARs: dict_keys(['0', '1', '10', '2', '7', 'ACM1', 'AVCCM', 'CCS', 'CME+', 'TVCM2', 'VCM'])

# %%
#feather_database_url='https://resources.aertslab.org/cistarget/databases/mus_musculus/mm10/screen/mc_v10_clust/region_based/mm10_screen_v10_clust.regions_vs_motifs.rankings.feather'

# %%
#!cd /temp_work/ch250798/Scenic/NFYA

# %%
#!wget "${feather_database_url}"
# Out:
# ://resources.aertslab.org/cistarget/databases/mus_musculus/mm10/screen/mc_v10_clust/region_based/mm10_screen_v10_clust.regions_vs_motifs.rankings.feather: Scheme missing.

# %%
#!wget -O NFYA/data/motifs-v10nr_clust-nr.mgi-m0.001-o0.0.tbl https://resources.aertslab.org/cistarget/motif2tf/motifs-v10nr_clust-nr.mgi-m0.001-o0.0.tbl

# %%
import dill
menr = dill.load(open(os.path.join(work_dir, 'motifs/menr.pkl'), 'rb'))

# %%
menr['DEM_topics_otsu_All'].DEM_results('Topic10')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 80px;"></th>
#       <th style="min-width: 80px;">Logo</th>
#       <th style="min-width: 80px;">Contrast</th>
#       <th style="min-width: 80px;">Direct_annot</th>
#       <th style="min-width: 80px;">Orthology_annot</th>
#       <th style="min-width: 80px;">Log2FC</th>
#       <th style="min-width: 80px;">Adjusted_pval</th>
#       <th style="min-width: 80px;">Mean_fg</th>
#       <th style="min-width: 80px;">Mean_bg</th>
#       <th style="min-width: 80px;">Motif_hit_thr</th>
#       <th style="min-width: 80px;">Motif_hits</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>taipale_cyt_meth__E2F2_GCGCGCGCGYW_eDBD_repr</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/taipale_cyt_meth__E2F2_GCGCGCGCGYW_eDBD_repr.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>E2f2</td>
#       <td>1.34632</td>
#       <td>0.001351</td>
#       <td>0.292454</td>
#       <td>0.11502</td>
#       <td>3.0</td>
#       <td>271.0</td>
#     </tr>
#     <tr>
#       <th>taipale_tf_pairs__E2F1_HES7_SRCRCGYGSYNNNNSGCGCSN_CAP_repr</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/taipale_tf_pairs__E2F1_HES7_SRCRCGYGSYNNNNSGCGCSN_CAP_repr.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Hes7, E2f1</td>
#       <td>1.33416</td>
#       <td>0.018424</td>
#       <td>0.161029</td>
#       <td>0.063868</td>
#       <td>3.0</td>
#       <td>106.0</td>
#     </tr>
#     <tr>
#       <th>kznf__ZBTB14_Schmitges2016_RCADE</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/kznf__ZBTB14_Schmitges2016_RCADE.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Zbtb14</td>
#       <td>1.215985</td>
#       <td>0.0</td>
#       <td>0.513023</td>
#       <td>0.220846</td>
#       <td>3.0</td>
#       <td>543.0</td>
#     </tr>
#     <tr>
#       <th>metacluster_144.3</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/metacluster_144.3.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Zfp704</td>
#       <td>1.200165</td>
#       <td>0.0</td>
#       <td>0.399517</td>
#       <td>0.17388</td>
#       <td>3.0</td>
#       <td>142.0</td>
#     </tr>
#     <tr>
#       <th>kznf__ZNF777_Imbeault2017_OM_MEME</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/kznf__ZNF777_Imbeault2017_OM_MEME.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Zfp777</td>
#       <td>1.163396</td>
#       <td>0.000011</td>
#       <td>0.177472</td>
#       <td>0.079234</td>
#       <td>3.0</td>
#       <td>248.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__ZBTB2_NTTTMCGGTWAN_eDBD</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/taipale_cyt_meth__ZBTB2_NTTTMCGGTWAN_eDBD.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Zbtb2</td>
#       <td>1.132544</td>
#       <td>0.000073</td>
#       <td>0.339235</td>
#       <td>0.154729</td>
#       <td>3.0</td>
#       <td>265.0</td>
#     </tr>
#     <tr>
#       <th>kznf__ZNF2_Imbeault2017_RP_ChIP-seq</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/kznf__ZNF2_Imbeault2017_RP_ChIP-seq.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Zfp661</td>
#       <td>1.131242</td>
#       <td>0.0</td>
#       <td>0.565852</td>
#       <td>0.258324</td>
#       <td>3.0</td>
#       <td>485.0</td>
#     </tr>
#     <tr>
#       <th>metacluster_55.3</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/metacluster_55.3.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>Nrf1, Zscan10, Nfe2l1</td>
#       <td>Egr1, Nrf1, Zbtb2, E2f6</td>
#       <td>1.075695</td>
#       <td>0.000031</td>
#       <td>0.52615</td>
#       <td>0.249628</td>
#       <td>3.0</td>
#       <td>491.0</td>
#     </tr>
#     <tr>
#       <th>kznf__ZNF777_Imbeault2017_RP_ChIP-seq</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/kznf__ZNF777_Imbeault2017_RP_ChIP-seq.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Zfp777</td>
#       <td>1.071077</td>
#       <td>0.000144</td>
#       <td>0.300084</td>
#       <td>0.142829</td>
#       <td>3.0</td>
#       <td>207.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__KLF3_NRCCGCAGCCCN_FL_meth_repr</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/taipale_cyt_meth__KLF3_NRCCGCAGCCCN_FL_meth_repr.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Klf3</td>
#       <td>1.069874</td>
#       <td>0.015606</td>
#       <td>0.262243</td>
#       <td>0.124922</td>
#       <td>3.0</td>
#       <td>225.0</td>
#     </tr>
#     <tr>
#       <th>metacluster_81.7</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/metacluster_81.7.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Creb1</td>
#       <td>1.034539</td>
#       <td>0.049913</td>
#       <td>0.186129</td>
#       <td>0.090863</td>
#       <td>3.0</td>
#       <td>161.0</td>
#     </tr>
#     <tr>
#       <th>metacluster_198.3</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/metacluster_198.3.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Zfp64</td>
#       <td>0.994693</td>
#       <td>0.0</td>
#       <td>0.743503</td>
#       <td>0.373122</td>
#       <td>3.0</td>
#       <td>673.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M04883</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/transfac_pro__M04883.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Tcf12</td>
#       <td>0.976699</td>
#       <td>0.0</td>
#       <td>0.824448</td>
#       <td>0.418936</td>
#       <td>3.0</td>
#       <td>966.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M04845</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/transfac_pro__M04845.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Zbtb7a</td>
#       <td>0.948556</td>
#       <td>0.0</td>
#       <td>0.734821</td>
#       <td>0.380748</td>
#       <td>3.0</td>
#       <td>765.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M05845</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/transfac_pro__M05845.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Zscan29</td>
#       <td>0.933931</td>
#       <td>0.001601</td>
#       <td>0.307309</td>
#       <td>0.160855</td>
#       <td>3.0</td>
#       <td>263.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M04748</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/transfac_pro__M04748.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Gabpa</td>
#       <td>0.928649</td>
#       <td>0.000003</td>
#       <td>0.571355</td>
#       <td>0.300161</td>
#       <td>3.0</td>
#       <td>434.0</td>
#     </tr>
#     <tr>
#       <th>homer__TWVGGTCCGC_HINFP</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/homer__TWVGGTCCGC_HINFP.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Hinfp</td>
#       <td>0.928435</td>
#       <td>0.0</td>
#       <td>0.511335</td>
#       <td>0.26867</td>
#       <td>3.0</td>
#       <td>292.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M12697</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/transfac_pro__M12697.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Zfp142</td>
#       <td>0.928315</td>
#       <td>0.0</td>
#       <td>0.5992</td>
#       <td>0.314863</td>
#       <td>3.0</td>
#       <td>440.0</td>
#     </tr>
#     <tr>
#       <th>kznf__CTCF_Transfac.4_Transfac</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/kznf__CTCF_Transfac.4_Transfac.png" width="200" ></td>
#       <td>Topic10</td>
#       <td>NaN</td>
#       <td>Ctcf</td>
#       <td>0.926274</td>

# %%
region_sets['DARs']
# Out:
# {'0': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 43118524  | 43119024  |
#  | chr1         | 37805853  | 37806353  |
#  | chr1         | 92161655  | 92162155  |
#  | chr1         | 128570987 | 128571487 |
#  | ...          | ...       | ...       |
#  | chrX         | 6091976   | 6092476   |
#  | chrX         | 105684383 | 105684883 |
#  | chrX         | 153359314 | 153359814 |
#  | chrX         | 73774987  | 73775487  |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 14,928 rows and 3 columns from 20 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  '1': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 37805853  | 37806353  |
#  | chr1         | 43118524  | 43119024  |
#  | chr1         | 92161655  | 92162155  |
#  | chr1         | 135003020 | 135003520 |
#  | ...          | ...       | ...       |
#  | chrX         | 140599080 | 140599580 |
#  | chrX         | 100741908 | 100742408 |
#  | chrX         | 160964462 | 160964962 |
#  | chrX         | 59182280  | 59182780  |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 13,933 rows and 3 columns from 20 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  '10': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 128580119 | 128580619 |
#  | chr1         | 166819329 | 166819829 |
#  | chr1         | 182732571 | 182733071 |
#  | chr1         | 54683940  | 54684440  |
#  | ...          | ...       | ...       |
#  | chrX         | 7657772   | 7658272   |
#  | chrX         | 100774497 | 100774997 |
#  | chrX         | 48341569  | 48342069  |
#  | chrX         | 7789606   | 7790106   |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 20,171 rows and 3 columns from 20 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  '2': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 172391937 | 172392437 |
#  | chr1         | 91019310  | 91019810  |
#  | chr1         | 39547205  | 39547705  |
#  | chr1         | 178687061 | 178687561 |
#  | ...          | ...       | ...       |
#  | chrX         | 11493379  | 11493879  |
#  | chrX         | 141385424 | 141385924 |
#  | chrX         | 100777691 | 100778191 |
#  | chrX         | 9270958   | 9271458   |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 9,791 rows and 3 columns from 20 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  '3': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 150889913 | 150890413 |
#  | chr1         | 133400315 | 133400815 |
#  | chr1         | 150027118 | 150027618 |
#  | chr1         | 156459421 | 156459921 |
#  | ...          | ...       | ...       |
#  | chrX         | 169053977 | 169054477 |
#  | chrX         | 7662814   | 7663314   |
#  | chrX         | 96025812  | 96026312  |
#  | chrX         | 166384940 | 166385440 |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 2,337 rows and 3 columns from 20 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  '7': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 166819329 | 166819829 |
#  | chr1         | 128580119 | 128580619 |
#  | chr1         | 182732571 | 182733071 |
#  | chr1         | 71956941  | 71957441  |
#  | ...          | ...       | ...       |
#  | chrX         | 48341569  | 48342069  |
#  | chrX         | 150848043 | 150848543 |
#  | chrX         | 73465415  | 73465915  |
#  | chrX         | 36807823  | 36808323  |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 21,291 rows and 3 columns from 20 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'ACM1': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 187435232 | 187435732 |
#  | chr1         | 13647837  | 13648337  |
#  | chr1         | 41590287  | 41590787  |
#  | chr1         | 127660326 | 127660826 |
#  | ...          | ...       | ...       |
#  | chrX         | 10535479  | 10535979  |
#  | chrX         | 6925579   | 6926079   |
#  | chrX         | 93755278  | 93755778  |
#  | chrX         | 106016109 | 106016609 |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 17,320 rows and 3 columns from 20 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'AVCCM': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 88474384  | 88474884  |
#  | chr1         | 150027118 | 150027618 |
#  | chr1         | 133965249 | 133965749 |
#  | chr1         | 150889913 | 150890413 |
#  | ...          | ...       | ...       |
#  | chrX         | 77490100  | 77490600  |
#  | chrX         | 99196469  | 99196969  |
#  | chrX         | 11417754  | 11418254  |
#  | chrX         | 104670536 | 104671036 |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 17,851 rows and 3 columns from 20 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'CCS': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 187435232 | 187435732 |
#  | chr1         | 13647837  | 13648337  |
#  | chr1         | 127660326 | 127660826 |
#  | chr1         | 13925890  | 13926390  |
#  | ...          | ...       | ...       |
#  | chrX         | 52287221  | 52287721  |
#  | chrX         | 44367623  | 44368123  |
#  | chrX         | 157698819 | 157699319 |
#  | chrX         | 50566237  | 50566737  |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 14,994 rows and 3 columns from 20 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'CME+': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 186161025 | 186161525 |
#  | chr1         | 158992732 | 158993232 |
#  | chr1         | 91693022  | 91693522  |
#  | chr1         | 45193180  | 45193680  |
#  | ...          | ...       | ...       |
#  | chrX         | 95968341  | 95968841  |
#  | chrX         | 11418512  | 11419012  |
#  | chrX         | 152336431 | 152336931 |
#  | chrX         | 151096155 | 151096655 |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 19,306 rows and 3 columns from 20 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'TVCM2': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 78021034  | 78021534  |
#  | chr1         | 190309933 | 190310433 |
#  | chr1         | 126766920 | 126767420 |
#  | chr1         | 81795539  | 81796039  |
#  | ...          | ...       | ...       |
#  | chrX         | 134752560 | 134753060 |
#  | chrX         | 142575127 | 142575627 |
#  | chrX         | 129799917 | 129800417 |
#  | chrX         | 99856688  | 99857188  |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 19,659 rows and 3 columns from 20 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'VCM': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 130995507 | 130996007 |
#  | chr1         | 54683940  | 54684440  |
#  | chr1         | 64658849  | 64659349  |
#  | chr1         | 71956941  | 71957441  |
#  | ...          | ...       | ...       |
#  | chrX         | 104670536 | 104671036 |
#  | chrX         | 103981172 | 103981672 |
#  | chrX         | 95968341  | 95968841  |
#  | chrX         | 48341569  | 48342069  |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 18,654 rows and 3 columns from 20 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.}

# %%
#sbatch run_AFmultiomeN4.sh 
#Which is creating scenicplus object
